# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
cars_data=pd.read_csv("datasets/Toyota.csv",index_col=0,na_values=["??","????"])
cars_data.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
cars_data.dtypes
# Out:
# Price          int64
# Age          float64
# KM           float64
# FuelType      object
# HP           float64
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors         object
# Weight         int64
# dtype: object

# %%
cars_data["HP"].unique()
# Out:
# array([ 90.,  nan, 192., 110.,  97.,  71., 116.,  98.,  69.,  86.,  72.,
#        107.,  73.])

# %%
cars_data["Doors"].unique()
# Out:
# array(['three', '3', '5', '4', 'four', 'five', '2'], dtype=object)

# %%
sns.scatterplot(x="Age",y="Price",markers="#",data=cars_data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.regplot(x="Age",y="Price",fit_reg=False,data=cars_data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.lmplot(x="Age",y="Price",data=cars_data,hue="FuelType",palette="PuRd_r",fit_reg=False)

# %%
sns.displot(cars_data.Age,kde=False,bins=8)

# %%
sns.countplot(data=cars_data,x="FuelType")
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
sns.countplot(data=cars_data,x="FuelType",hue="Automatic")
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
pd.crosstab(index=cars_data["Automatic"],columns=cars_data["FuelType"],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           15     144    1104
# 1            0       0      73

# %%
sns.boxplot(x=cars_data["FuelType"],y=cars_data["Price"])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
sns.boxplot(x=cars_data["FuelType"],y=cars_data["Price"],hue="Automatic",data=cars_data)
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
f,(ax_box,ax_hist)=plt.subplots(2, gridspec_kw={'height_ratios':(.15,.85)})

# %%
f,(ax_box,ax_hist)=plt.subplots(2, gridspec_kw={'height_ratios':(.15,.85)})
sns.boxplot(cars_data['Price'],ax=ax_box)
sns.displot(cars_data['Price'],ax=ax_hist)
# Out:
# C:\Users\DSAI\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DSAI\Anaconda3\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(cars_data,kind="scatter",hue="FuelType",diag_kws={"bw_method":0.1})
plt.show()

# %%
randomdata=np.random.randint(20,100,(10,10))
print("data to be plotted")
print(randomdata)
# Out:
# data to be plotted
# [[42 52 95 33 99 63 25 70 27 86]
#  [85 29 57 34 37 46 36 45 79 65]
#  [59 46 89 51 81 39 51 94 68 50]
#  [41 44 96 87 90 52 97 86 75 81]
#  [32 95 43 51 55 58 66 84 32 53]
#  [95 24 57 32 80 56 44 48 60 20]
#  [63 94 69 74 37 36 87 66 56 82]
#  [48 81 51 21 70 40 26 67 81 31]
#  [82 20 31 40 61 84 24 45 81 20]
#  [41 57 70 90 88 95 57 66 30 94]]

# %%
sns.heatmap(randomdata)
plt.show()

# %%
sns.heatmap(randomdata,vmin=30,vmax=70)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(randomdata,cmap="copper",annot=True)
# Out:
# <AxesSubplot:>
